# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/ner-data/train.json
# /kaggle/input/ner-data/tag.txt
# /kaggle/input/ner-data/dev.json
# /kaggle/input/ner-data/onlyner_bio/train.txt
# /kaggle/input/ner-data/onlyner_bio/dev.txt
# /kaggle/input/ner-data/onlyner_bio/labels.txt
# /kaggle/input/ner-data/onlyner_bio/test.txt
# /kaggle/input/bert-ner-model/model/test_predictions.txt
# /kaggle/input/bert-ner-model/model/config.json
# /kaggle/input/bert-ner-model/model/vocab.txt
# /kaggle/input/bert-ner-model/model/pytorch_model.bin
# /kaggle/input/bert-ner-model/model/test_results.txt
# /kaggle/input/bert-ner-model/model/eval_results.txt
# /kaggle/input/bert-ner-model/model/special_tokens_map.json
# /kaggle/input/bert-ner-model/model/training_args.bin
# /kaggle/input/bert-ner-model/model/tokenizer_config.json
# /kaggle/input/chinese-wwm-ext-pytorch/config_bert.json
# /kaggle/input/chinese-wwm-ext-pytorch/config.json
# /kaggle/input/chinese-wwm-ext-pytorch/chinese_wwm_ext_pytorch/chinese_wwm_ext_pytorch/config.json
# ...

# %%
# %cd /kaggle/
# !wget https://github.com/huggingface/transformers/raw/c1a6252be173b417e46823d58d51d757344d88ee/examples/ner/run_ner.py
# !wget https://github.com/huggingface/transformers/raw/c1a6252be173b417e46823d58d51d757344d88ee/examples/ner/utils_ner.py
# !wget https://raw.githubusercontent.com/huggingface/transformers/c1a6252be173b417e46823d58d51d757344d88ee/examples/requirements.txt
# !rm run_ner.py
# !rm utils_ner.py
# !rm requirements.txt
# !wget https://github.com/napoler/tmark_Description/raw/master/ner_train/run_ner.py
# !wget https://raw.githubusercontent.com/napoler/tmark_Description/master/ner_train/utils_ner.py
# !wget https://github.com/napoler/tmark_Description/raw/master/ner_train/requirements.txt
# Out:
# /kaggle
# rm: cannot remove 'run_ner.py': No such file or directory
# rm: cannot remove 'utils_ner.py': No such file or directory
# rm: cannot remove 'requirements.txt': No such file or directory
# --2020-04-09 15:29:03--  https://github.com/napoler/tmark_Description/raw/master/ner_train/run_ner.py
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/napoler/tmark_Description/master/ner_train/run_ner.py [following]
# --2020-04-09 15:29:04--  https://raw.githubusercontent.com/napoler/tmark_Description/master/ner_train/run_ner.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 59 kB 1.8 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 4.3 MB/s
# ...
#      |████████████████████████████████| 17.1 MB 39.0 MB/s
# ...
# done
#   Created wheel for seqeval: filename=seqeval-0.0.12-py3-none-any.whl size=7423 sha256=217c32868fa184641570cb5143148ab013e740055b72150f95177975e4bcb41c
#   Stored in directory: /root/.cache/pip/wheels/1f/1b/a6/a808a7e4d1f7584e42f5e279664cd48bf24ed8392218ce6be4
# Successfully built seqeval
# ...

# %%
# !mkdir data
# !cp /kaggle/input/ner-data/onlyner_bio/* data


# !mkdir model
# !cp /kaggle/input/chinese-wwm-ext-pytorch/chinese_wwm_ext_pytorch/chinese_wwm_ext_pytorch/* model
# !rm model/config.json
# !cp /kaggle/input/chinese-wwm-ext-pytorch/config_bert.json model/config.json

# !cp /kaggle/input/bert-ner-model/model/* model




# # # 小数据测试
# !rm -rf  data/*
# ! head -100000 /kaggle/input/ner-data/onlyner_bio/train.txt > data/train.txt
# ! head -20000 /kaggle/input/ner-data/onlyner_bio/dev.txt > data/dev.txt
# ! head -20000 /kaggle/input/ner-data/onlyner_bio/test.txt > data/test.txt
# !head -999 /kaggle/input/ner-data/onlyner_bio/labels.txt > data/labels.txt

# %%
# !ls -l /kaggle/input/ner-data/onlyner_bio/
# !ls -l data/
# Out:
# total 50364
# -rw-r--r-- 1 nobody nogroup  8262727 Apr  9 14:39 dev.txt
# -rw-r--r-- 1 nobody nogroup       37 Apr  9 14:39 labels.txt
# -rw-r--r-- 1 nobody nogroup  8207690 Apr  9 14:39 test.txt
# -rw-r--r-- 1 nobody nogroup 35091818 Apr  9 14:39 train.txt
# total 50364
# -rw-r--r-- 1 root root  8262727 Apr  9 15:29 dev.txt
# -rw-r--r-- 1 root root       37 Apr  9 15:29 labels.txt
# -rw-r--r-- 1 root root  8207690 Apr  9 15:29 test.txt
# -rw-r--r-- 1 root root 35091818 Apr  9 15:29 train.txt

# %%
# !rm -rf /kaggle/working/model/*
# !mkdir /kaggle/working/model

# %%
# !python3 run_ner.py --max_seq_length  512 --num_train_epochs 4 --per_gpu_train_batch_size 17  --data_dir ./data --model_type bert  --labels ./data/labels.txt --model_name_or_path /kaggle/model/ --output_dir working/model  --save_steps 10000 --seed 1 --overwrite_output_dir --do_train --do_eval --do_predict
# !python3 run_ner.py --max_seq_length  128 --num_train_epochs 5 --per_gpu_train_batch_size 128  --data_dir ./data --model_type bert  --labels ./data/labels.txt --model_name_or_path /kaggle/model/ --output_dir working/model  --save_steps 10000000 --seed 1 --overwrite_output_dir --do_train --do_eval --do_predict
# Out:
# 2020-04-09 15:29:34.852084: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...
# Iteration:  76%|██████████████████████▊       | 499/656 [11:18<03:32,  1.36s/it]/opt/conda/lib/python3.6/site-packages/torch/optim/lr_scheduler.py:224: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
#
# ...
# Iteration:  89%|██████████████████████████▊   | 585/656 [13:15<01:36,  1.36s/it]
# ...
# ...
# Evaluating: 100%|███████████████████████████| 2247/2247 [01:33<00:00, 24.11it/s]
